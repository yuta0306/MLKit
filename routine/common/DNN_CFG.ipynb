# %%
class CFG:
    ##########
    #  Globals  #
    #########
    seed = 42
    epochs = 30
    train = True
    
    ########
    #  Data. #
    #######
    train_datadir = Path('')
    
    ##########
    #  Dataset  #
    ##########
    trainsforms = {
        'train': [{'name': None}],
        'valid': [{'name': None}],
    }
    # Any settings below
    
    target_columns = None
    
    ##########
    #  Loaders #
    ##########
    loader_params = {
        'train': {
            'batch_size': 32,
            'num_workers': 4,
            'suffle': True,
        },
        'valid': {
            'batch_size': 64,
            'num_workers': 4,
            'suffle': False,
        },
    }
    
    #######
    #  Split. #
    #######
    split = 'StratifiedKFold'
    split_params = {
        'n_split': 5,
        'shuffle': True,
        'random_state': 42,
    }
    
    #########
    #  Model. #
    #########
    base_model_name = ''
    pretrained = True
    num_classes = None
    in_channels = 1
    
    ###########
    #  Criterion  #
    ###########
    loss_name = ''
    loss_params: dict = {}
        
    ############
    #  Optimizer  #
    ############
    optimizer_name = 'Adam'
    base_optimizer = 'Adam'
    optimizer_params = {
        'lr': .001,
    }
    
    ############
    #  Scheduler  #
    ############
    scheduler_name = ''
    scheduler_params = {
        
    }
